# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Breast_Cancer.csv")
data.head()
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
def entropy(y):
    m = len(y)
    if m == 0:
        return 0
    p1 = np.sum(y==1)/m
    p0 = 1 - p1
    if p1 == 0 or p0 == 0:
        return 0
    return -(p1 * np.log2(p1) + p0 * np.log2(p0))

# %%
def information_gain(X_column,y,threshold):
    parent_entropy = entropy(y)

# %%
def information_gain(X_column, y, threshold):
    """
    Compute information gain of a binary split on X_column using given threshold.
    - For numeric columns: split is X_column <= threshold vs > threshold
    - For non-numeric (categorical) columns: split is X_column == threshold vs != threshold

    Parameters
    - X_column: array-like (pandas Series or numpy array) of feature values
    - y: numpy array of binary labels (0/1)
    - threshold: numeric threshold for continuous features or category value for categorical features

    Returns
    - information gain (float)
    """
    X_col = np.array(X_column)
    y = np.array(y)

    parent_entropy = entropy(y)
    if parent_entropy == 0:
        return 0.0

    # Decide split type: numeric vs categorical
    try:
        is_numeric = np.issubdtype(X_col.dtype, np.number)
    except TypeError:
        is_numeric = False

    if is_numeric:
        left_mask = X_col <= threshold
    else:
        left_mask = X_col == threshold

    y_left = y[left_mask]
    y_right = y[~left_mask]

    n = len(y)
    n_left = len(y_left)
    n_right = len(y_right)

    # If a split doesn't divide the data, information gain is zero
    if n_left == 0 or n_right == 0:
        return 0.0

    child_entropy = (n_left / n) * entropy(y_left) + (n_right / n) * entropy(y_right)
    return parent_entropy - child_entropy
